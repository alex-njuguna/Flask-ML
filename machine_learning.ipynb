# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("iceCreamData.csv")
df.head()
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %%
X = df["Temperature"]
y = df["Revenue"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

len(X_test)
len(X_train)
# Out:
# 400

# %%
model = LinearRegression()
model.fit(np.array(X_train).reshape(-1,1), y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(np.array(X_test).reshape(-1,1))
y_pred
# Out:
# array([467.98320449, 788.16591747, 314.71144928, 543.34172776,
#        508.11458656, 666.42535628, 339.04680182, 250.15567233,
#        469.89920538, 580.64580815, 837.83262287, 697.75840476,
#        526.23637053, 202.57083528, 351.45612562, 705.83784592,
#        123.95402766,  45.46798879, 606.41359193, 563.41412283,
#        136.2001401 , 620.72128534, 291.83780304, 312.38607285,
#        774.96508708, 246.86181687, 547.15244644, 449.82759695,
#        514.5531134 , 693.27174084, 639.30426444, 239.80191345,
#        381.21049207, 912.29732264, 415.17122942, 550.41780438,
#        602.22283657, 434.16316279, 200.17068405, 353.53116148,
#        546.8571956 , 600.92457736, 569.59280319, 262.20187016,
#        509.88221275, 662.00700707, 673.09249833, 516.85232902,
#        671.93776887, 664.42190078, 708.64564575, 315.06789541,
#        679.18436423, 654.49246662, 326.29670053, 506.79888667,
#        473.44003518, 795.77771186, 599.43755923, 485.72932255,
#        441.86058642, 514.44417223, 586.05635466, 828.66683549,
#        410.62133775, 130.84714938, 572.02311731, 476.58153098,
#        676.49237248, 461.66927696, 159.80049702, 663.68081504,
#        696.70630874, 443.88212917, 622.798661  , 430.82357264,
#        419.30428281, 622.08945803, 382.86953691, 872.78033843,
#        422.15724199, 609.52728019, 538.13251919, 579.81474917,
#        576.14138637, 576.15158919, 583.37755961, 456.56526759,
#        622.52887599, 539.26172286, 282.72158219, 582.09705976,
#        357.11054842, 530.62902753, 681.6409411 , 862.44602564,
#        440.8871088 , 646.13638296, 360.9787065 , 739.57505907])

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9815824532036581

# %%
model.predict([[1]])
# Out:
# array([66.88493709])

# %%
with open("model.pkl", "wb") as model_file:
    pickle.dump(model, model_file)
